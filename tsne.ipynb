# %%
import numpy as np
import matplotlib.pyplot as plt
from main import make_dataset, get_pcd, get_audios
from dataset_utils import get_Raga
from joblib import Parallel, delayed

# %%
import dataset_utils
import os
from dataset_utils import get_random_songs
# len(labels[3])

X = np.load(dataset_utils.copy_base+'DATASET_toy_X.npy')
y = np.load(dataset_utils.copy_base+'DATASET_toy_Y.npy')
print(X.shape,y.shape)
# Out:
# (60, 124044) (60,)

# %%
from sklearn.decomposition import PCA
from sklearn.manifold import TSNE
# %matplotlib inline
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
import seaborn as sns
sns.set(rc={'figure.figsize':(11.7, 8.27)})
pallete = sns.color_palette("bright", 3)

pca_32 = PCA(n_components=32)

pca32_result = pca_32.fit_transform(X=X)
print('Cumulative explained variation for 50 principal components: {}'.format(np.sum(pca_32.explained_variance_ratio_)))
print(pca32_result.shape)
# Out:
# Cumulative explained variation for 50 principal components: 0.7299567357694965
# (60, 32)

# %%
tsne = TSNE()
tsne_result = tsne.fit_transform(pca32_result)
sns.scatterplot(tsne_result[:, 0], tsne_result[:, 1], hue=y, legend='full', palette=pallete)
